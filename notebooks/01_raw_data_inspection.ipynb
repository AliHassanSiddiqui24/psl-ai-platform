# %%
import os
os.chdir("..") # Ek folder piche jane ke liye
print(os.getcwd()) # Check karein ke ab path 'psl_ai_platform' par hai ya nahi
# Out:
# c:\Users\User\Desktop\psl_ai_platform

# %%
from pathlib import Path
import pandas as pd

# %%
inventory_path = Path("data/raw/cricsheet_psl/dataset_inventory.csv")
inventory_df = pd.read_csv(inventory_path)
inventory_df.head()
# Out:
#       file_name                                          file_path  \
# 0  1075986.yaml  C:\Users\User\Desktop\psl_ai_platform\data\raw...
# 1  1075987.yaml  C:\Users\User\Desktop\psl_ai_platform\data\raw...
# 2  1075988.yaml  C:\Users\User\Desktop\psl_ai_platform\data\raw...
# 3  1075989.yaml  C:\Users\User\Desktop\psl_ai_platform\data\raw...
# 4  1075990.yaml  C:\Users\User\Desktop\psl_ai_platform\data\raw...
#
#    file_size_bytes file_extension
# 0            44803          .yaml
# 1            45899          .yaml
# 2            44073          .yaml
# 3            44606          .yaml
# 4            45628          .yaml

# %%
inventory_df.shape
# Out:
# (336, 4)

# %%
inventory_df["file_extension"].value_counts()
# Out:
# file_extension
# .yaml    335
# .txt       1
# Name: count, dtype: int64
