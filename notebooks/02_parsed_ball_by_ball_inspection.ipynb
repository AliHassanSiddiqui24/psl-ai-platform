# %%
import os
os.chdir("..") # Ek folder piche jane ke liye
print(os.getcwd()) # Check karein ke ab path 'psl_ai_platform' par hai ya nahi
# Out:
# c:\Users\User\Desktop\psl_ai_platform

# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path("data/interim/ball_by_ball/psl_ball_by_ball.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    match_id  innings_number    batting_team  over  ball  batter  \
# 0   1075986               1  Peshawar Zalmi     0     1     NaN
# 1   1075986               1  Peshawar Zalmi     0     2     NaN
# 2   1075986               1  Peshawar Zalmi     0     3     NaN
# 3   1075986               1  Peshawar Zalmi     0     4     NaN
# 4   1075986               1  Peshawar Zalmi     0     5     NaN
#
#            bowler   non_striker  runs_batter  runs_extras  ...  wicket_type  \
# 0  Mohammad Irfan      DJ Malan            0            0  ...          NaN
# 1  Mohammad Irfan      DJ Malan            0            0  ...          NaN
# 2  Mohammad Irfan  Kamran Akmal            0            0  ...          NaN
# 3  Mohammad Irfan  Kamran Akmal            0            0  ...          NaN
# 4  Mohammad Irfan  Kamran Akmal            0            0  ...          NaN
#
#   player_out  fielders_involved  match_date  city  \
# 0        NaN                NaN  2017-02-09   NaN
# 1        NaN                NaN  2017-02-09   NaN
# 2        NaN                NaN  2017-02-09   NaN
# 3        NaN                NaN  2017-02-09   NaN
# 4        NaN                NaN  2017-02-09   NaN
#
#                                  venue             team1           team2  \
# 0  Dubai International Cricket Stadium  Islamabad United  Peshawar Zalmi
# 1  Dubai International Cricket Stadium  Islamabad United  Peshawar Zalmi
# 2  Dubai International Cricket Stadium  Islamabad United  Peshawar Zalmi
# 3  Dubai International Cricket Stadium  Islamabad United  Peshawar Zalmi
# 4  Dubai International Cricket Stadium  Islamabad United  Peshawar Zalmi
#
#         toss_winner toss_decision
# 0  Islamabad United         field
# 1  Islamabad United         field
# 2  Islamabad United         field
# 3  Islamabad United         field
# 4  Islamabad United         field
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (78660, 23)

# %%
df.columns.tolist()
# Out:
# ['match_id',
#  'innings_number',
#  'batting_team',
#  'over',
#  'ball',
#  'batter',
#  'bowler',
#  'non_striker',
#  'runs_batter',
#  'runs_extras',
#  'runs_total',
#  'extras_type',
#  'wicket',
#  'wicket_type',
#  'player_out',
#  'fielders_involved',
#  'match_date',
#  'city',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision']

# %%
df.isna().sum().sort_values(ascending=False).head(20)
# Out:
# batter               78660
# fielders_involved    78660
# player_out           78660
# wicket_type          78660
# extras_type          74379
# city                  9887
# wicket                   0
# toss_winner              0
# team2                    0
# team1                    0
# venue                    0
# match_date               0
# match_id                 0
# innings_number           0
# runs_total               0
# runs_extras              0
# runs_batter              0
# non_striker              0
# bowler                   0
# ball                     0
# dtype: int64

# %%
df["wicket"].value_counts(dropna=False)
# Out:
# wicket
# 0    78660
# Name: count, dtype: int64
